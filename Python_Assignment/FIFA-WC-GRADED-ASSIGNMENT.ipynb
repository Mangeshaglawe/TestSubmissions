# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
sns.set(style ="ticks")

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('fifa.csv')
df1 = pd.read_csv('fifa_ variable_information.csv')
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df1.head()
# Out:
#             ID     unique id for every player
# 0         Name                           name
# 1          Age                            age
# 2        Photo      url to the player's photo
# 3  Nationality                    nationality
# 4         Flag  url to players's country flag

# %%
df.info
# Out:
# <bound method DataFrame.info of            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of                           ID          unique id for every player
# 0                       Name                                name
# 1                        Age                                 age
# 2                      Photo           url to the player's photo
# 3                Nationality                         nationality
# 4                       Flag       url to players's country flag
# 5                    Overall                      overall rating
# 6                  Potential                    potential rating
# 7                       Club                        current club
# 8                  Club Logo                    url to club logo
# 9                      Value                current market value
# 10                      Wage                        current wage
# 11            Preferred Foot                          left/right
# 12  International Reputation                rating on scale of 5
# ...

# %%
df.drop('Photo',axis=1,inplace=True)

# %%
df.drop('Flag',axis=1,inplace=True)

# %%
df.drop('Club Logo',axis=1,inplace=True)

# %%
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  €110.5M  €565K           Left  ...       96.0
# 1             Juventus     €77M  €405K          Right  ...       95.0
# 2  Paris Saint-Germain  €118.5M  €290K          Right  ...       94.0
# 3    Manchester United     €72M  €260K          Right  ...       68.0
# 4      Manchester City    €102M  €355K          Right  ...       88.0
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling  GKKicking  \
# ...

# %%
df['Value'] = df['Value'].str.replace('€', '')
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club   Value   Wage Preferred Foot  ...  Composure  Marking  \
# 0         FC Barcelona  110.5M  €565K           Left  ...       96.0     33.0
# 1             Juventus     77M  €405K          Right  ...       95.0     28.0
# 2  Paris Saint-Germain  118.5M  €290K          Right  ...       94.0     27.0
# 3    Manchester United     72M  €260K          Right  ...       68.0     15.0
# 4      Manchester City    102M  €355K          Right  ...       88.0     68.0
#
#    StandingTackle SlidingTackle GKDiving GKHandling  GKKicking GKPositioning  \
# ...

# %%
df['Wage'] = df['Wage'].str.replace('€', '')
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value  Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  110500000.0  565K           Left  ...       96.0
# 1             Juventus   77000000.0  405K          Right  ...       95.0
# 2  Paris Saint-Germain  118500000.0  290K          Right  ...       94.0
# 3    Manchester United   72000000.0  260K          Right  ...       68.0
# 4      Manchester City  102000000.0  355K          Right  ...       88.0
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling  GKKicking  \
# ...

# %%
df['Release Clause'] = df['Release Clause'].str.replace('€', '')
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value  Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  110500000.0  565K           Left  ...       96.0
# 1             Juventus   77000000.0  405K          Right  ...       95.0
# 2  Paris Saint-Germain  118500000.0  290K          Right  ...       94.0
# 3    Manchester United   72000000.0  260K          Right  ...       68.0
# 4      Manchester City  102000000.0  355K          Right  ...       88.0
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling  GKKicking  \
# ...

# %%
#df['Value'] = df['Value'].str.contains('M', '')
df['Value'] =df['Value'].replace({"K":"*1e3","M":"*1e6"},regex=True).map(pd.eval).astype(float)
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value   Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  110500000.0  €565K           Left  ...       96.0
# 1             Juventus   77000000.0  €405K          Right  ...       95.0
# 2  Paris Saint-Germain  118500000.0  €290K          Right  ...       94.0
# 3    Manchester United   72000000.0  €260K          Right  ...       68.0
# 4      Manchester City  102000000.0  €355K          Right  ...       88.0
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling  GKKicking  \
# ...

# %%
df['Wage'] =df['Wage'].replace({"K":"*1e3","M":"*1e6"},regex=True).map(pd.eval).astype(float)
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value      Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  110500000.0  565000.0           Left  ...       96.0
# 1             Juventus   77000000.0  405000.0          Right  ...       95.0
# 2  Paris Saint-Germain  118500000.0  290000.0          Right  ...       94.0
# 3    Manchester United   72000000.0  260000.0          Right  ...       68.0
# 4      Manchester City  102000000.0  355000.0          Right  ...       88.0
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling  GKKicking  \
# ...

# %%
df['Release Clause'] = df['Release Clause'].values.any()
df['Release Clause'] = df['Release Clause'].replace({"K":"*1e3","M":"*1e6"},regex=True).map(pd.eval).astype(float)
#= np.where(df['Release Clause'].isnull().values.any(),df['Release Clause'].replace({"K":"*1e3","M":"*1e6"},regex=True).map(pd.eval).astype(float),df['Release Clause'])
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value      Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  110500000.0  565000.0           Left  ...       96.0
# 1             Juventus   77000000.0  405000.0          Right  ...       95.0
# 2  Paris Saint-Germain  118500000.0  290000.0          Right  ...       94.0
# 3    Manchester United   72000000.0  260000.0          Right  ...       68.0
# 4      Manchester City  102000000.0  355000.0          Right  ...       88.0
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling  GKKicking  \
# ...

# %%
df['Joined'] = pd.to_datetime(df['Joined']).astype('datetime64[ns]').dt.year
print(df['Joined'])
#df['Joined']
#df['Joined'].apply(lambda x: datetime.datetime.strptime(x,'%Y-%m-%d %H:%M:%S'))
#df['Joined'] = pd.to_datetime(df['Joined'], format='%Y%m%d.0', errors='coerce').astype('datetime64[ns]')
#print(df['Joined'].year)
#print(pd.DatetimeIndex(df['Joined']))
#df['Joined'] = df["Joined"].astype('datetime64[ns]')
#print(pd.DatetimeIndex(df['Joined']).astype('datetime64[ns]').year)

#df['Joined'] = pd.to_datetime(df['Joined'], format='%y')
#print(df['Joined'])
#df.info()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 18202   NaN
# 18203   NaN
# 18204   NaN
# 18205   NaN
# 18206   NaN
# Name: Joined, Length: 18207, dtype: float64

# %%
df["Contract Valid Until"] = pd.to_datetime(df["Contract Valid Until"],  format='%y%m%d')
df["Contract Valid Until"]
# Out:
# 0       1970-01-01 00:00:00.000001970
# 1       1970-01-01 00:00:00.000001970
# 2       1970-01-01 00:00:00.000001970
# 3       1970-01-01 00:00:00.000001970
# 4       1970-01-01 00:00:00.000001970
#                      ...
# 18202   1970-01-01 00:00:00.000001970
# 18203   1970-01-01 00:00:00.000001970
# 18204   1970-01-01 00:00:00.000001970
# 18205   1970-01-01 00:00:00.000001970
# 18206   1970-01-01 00:00:00.000001970
# Name: Contract Valid Until, Length: 18207, dtype: datetime64[ns]

# %%
df['Height'] =df['Height'].replace({"'":"."},regex=True).astype(float)
df["Height"]
# Out:
# 0        5.70
# 1        6.20
# 2        5.90
# 3        6.40
# 4        5.11
#          ...
# 18202    5.90
# 18203    6.30
# 18204    5.80
# 18205    5.10
# 18206    5.10
# Name: Height, Length: 18207, dtype: float64

# %%
df['Weight'] =df['Weight'].replace({"lbs":""},regex=True).astype(float)
df["Weight"]
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
df["Weight"] = df["Weight"].fillna(0)
df["Weight"]
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
df.describe(include='O').T
# Out:
#                 count unique             top   freq
# Name            18207  17194    J. Rodríguez     11
# Nationality     18207    164         England   1662
# Club            17966    651    FC Barcelona     33
# Preferred Foot  18159      2           Right  13948
# Work Rate       18159      9  Medium/ Medium   9810
# Body Type       18159     10          Normal  10595
# Position        18147     27              ST   2152
# Loaned From      1264    341        Atalanta     20

# %%
#plt.plot(df['Name'],df['Overall'])
plt.scatter(df['Name'],df['Overall'])
plt.xlabel('Name')
plt.xlabel('Overall')
plt.show()
#df.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     18207 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18159 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Weak Foot                 18159 non-null  float64
#  12  Skill Moves               18159 non-null  float64
# ...

# %%
#df["Rank"] = df["Overall"].rank()
  
# display
df2 = df['Name'].head(20)
df2
  
# sorting w.r.t name column
#df.sort_values("Overall", inplace = True)
# Out:
# 0              L. Messi
# 1     Cristiano Ronaldo
# 2             Neymar Jr
# 3                De Gea
# 4          K. De Bruyne
# 5             E. Hazard
# 6             L. Modrić
# 7             L. Suárez
# 8          Sergio Ramos
# 9              J. Oblak
# 10       R. Lewandowski
# 11             T. Kroos
# 12             D. Godín
# 13          David Silva
# 14             N. Kanté
# 15            P. Dybala
# 16              H. Kane
# 17         A. Griezmann
# 18        M. ter Stegen
# 19          T. Courtois
# Name: Name, dtype: object

# %%
#df.sort_values('Overall', ascending=False).iloc[0:20,'Name'] 
df.head(20).sort_values(by='Overall',ascending=False)
#df.sort_values(by=['Overall','Name'])
#df.loc[0:20, 'Name']
# Out:
#         ID               Name  Age  \
# 0   158023           L. Messi   31
# 1    20801  Cristiano Ronaldo   33
# 2   190871          Neymar Jr   26
# 3   193080             De Gea   27
# 4   192985       K. De Bruyne   27
# 5   183277          E. Hazard   27
# 6   177003          L. Modrić   32
# 7   176580          L. Suárez   31
# 8   155862       Sergio Ramos   32
# 12  182493           D. Godín   32
# 13  168542        David Silva   32
# 10  188545     R. Lewandowski   29
# 11  182521           T. Kroos   28
# 9   200389           J. Oblak   25
# 14  215914           N. Kanté   27
# 15  211110          P. Dybala   24
# 16  202126            H. Kane   24
# 17  194765       A. Griezmann   27
# 18  192448      M. ter Stegen   26
# 19  192119        T. Courtois   26
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# ...

# %%
top20df = df.nlargest(20, ['Overall'])
top20df
# Out:
#         ID               Name  Age  \
# 0   158023           L. Messi   31
# 1    20801  Cristiano Ronaldo   33
# 2   190871          Neymar Jr   26
# 3   193080             De Gea   27
# 4   192985       K. De Bruyne   27
# 5   183277          E. Hazard   27
# 6   177003          L. Modrić   32
# 7   176580          L. Suárez   31
# 8   155862       Sergio Ramos   32
# 9   200389           J. Oblak   25
# 10  188545     R. Lewandowski   29
# 11  182521           T. Kroos   28
# 12  182493           D. Godín   32
# 13  168542        David Silva   32
# 14  215914           N. Kanté   27
# 15  211110          P. Dybala   24
# 16  202126            H. Kane   24
# 17  194765       A. Griezmann   27
# 18  192448      M. ter Stegen   26
# 19  192119        T. Courtois   26
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# ...

# %%
top20df["Age"].mean()
#top20df["Wage"].mean()
#top20df[["Age", "Wage"]].groupby("Age").mean()
# Out:
# 28.3

# %%
#top20df["Wage"]
#top20df["Wage"] = top20df["Wage"].str.replace('€', '')
#top20df["Wage"].replace({"K":"*1e3","M":"*1e6"},regex=True).map(pd.eval).astype(float)
#top20df[["Age", "Wage"]].groupby("Wage").mean().sort_values(by='Age',ascending=False)

#top20df[["Age", "Wage"]].median()


#top20df[["Age", "Wage"]].describe()

top20df.agg(
    {
        "Age": ["min", "max", "median", "skew"],
        "Wage": ["min", "max", "median", "mean"],
    }
)
# Out:
#               Age  Wage
# min     24.000000  125K
# max     33.000000   94K
# median  27.000000   NaN
# skew     0.238654   NaN

# %%
top20df[["Name", "Wage"]].head(1)
# Out:
#        Name  Wage
# 0  L. Messi  565K

# %%
#Average Overall Rating of Each Club
df_new = df[['Club','Name','Wage','Overall']]
#df_new.describe()
df_new[["Club", "Overall"]].groupby("Club").mean().sort_values(by='Overall',ascending=False)
# Out:
#                   Overall
# Club
# Juventus        82.280000
# Napoli          80.000000
# Inter           79.750000
# Real Madrid     78.242424
# Milan           78.074074
# ...                   ...
# Sligo Rovers    56.631579
# Derry City      55.777778
# Bohemian FC     55.000000
# Limerick FC     54.526316
# Bray Wanderers  53.652174
#
# [651 rows x 1 columns]

# %%
 #Display the average overall rating of Top10 Clubs using a plot
plt.xticks(rotation=45)    
plt.plot(df_new[["Club", "Overall"]].groupby("Club").mean().sort_values(by='Overall',ascending=False).head(10))

# %%
#df['Joined'] = df["Joined"].astype('datetime64[ns]')
#df['Joined'] = pd.DatetimeIndex(df["Joined"], format='%y%m%d')
#df.head()
#print(df['Joined'])
#print(pd.DatetimeIndex(df['Joined']).year)
#pd.DatetimeIndex((df["Joined"].astype('datetime64[ns]') ))

#print(pd.to_datetime(df["Joined"].dt.strftime('%Y')))

# %%
#df['Value'] = np.where(df['Value'].str.endswith('M'), df['Value']*1000000,df['Value']*1000)
#print(pd.to_datetime(df["Joined"].dt.strftime('%Y')))
#print((df['Joined']).isnull().values.any())
#= np.where(df['Release Clause'].isnan()
#df.head()

# %%
df['Value'] = df['Value'].str.replace('€', '')
df.head()
